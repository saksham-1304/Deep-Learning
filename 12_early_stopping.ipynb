# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
sns.scatterplot(x=X[:,0], y=X[:,1], hue=y)
# Out:
# <Axes: >

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, verbose=0)
#
# File c:\Users\HP\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\HP\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:397, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     395 callbacks.on_epoch_begin(epoch)
#     396 with epoch_iterator.catch_stop_iteration():
# --> 397     for begin_step, end_step, iterator in epoch_iterator:
#     398         callbacks.on_train_batch_begin(begin_step)
#     399         logs = self.train_function(iterator)
#
# File c:\Users\HP\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:764, in TFEpochIterator.__next__(self)
#     763 def __next__(self):
# --> 764     return next(self._epoch_iterator)
#
# File c:\Users\HP\anaconda3\Lib\site-packages\keras\src\trainers\epoch_iterator.py:125, in EpochIterator._enumerate_iterator(self)
#     119         yield (
#     120             step,
#     121             step + self.steps_per_execution - 1,
#     122             self._current_iterator,
#     123         )
#     124     if self._num_batches and self._steps_seen >= self._num_batches:
# --> 125         self._current_iterator = iter(self._get_iterator())
#     126         self._steps_seen = 0
#     127 else:
#
# File c:\Users\HP\anaconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\HP\anaconda3\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File c:\Users\HP\anaconda3\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\HP\anaconda3\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.plot(history.history['loss'], label='train')
#       2 plt.plot(history.history['val_loss'], label='test')
#       3 plt.legend()
#
# NameError: name 'history' is not defined

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %% [markdown]
# # Early Stopping

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.4750 - loss: 0.7003 - val_accuracy: 0.4500 - val_loss: 0.6904
# Epoch 2/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5125 - loss: 0.6976 - val_accuracy: 0.6000 - val_loss: 0.6933
# Epoch 3/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5250 - loss: 0.6959 - val_accuracy: 0.5500 - val_loss: 0.6934
# Epoch 4/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6944 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 5/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5125 - loss: 0.6928 - val_accuracy: 0.4500 - val_loss: 0.6937
# Epoch 6/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5250 - loss: 0.6919 - val_accuracy: 0.4500 - val_loss: 0.6942
# Epoch 7/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5250 - loss: 0.6907 - val_accuracy: 0.4500 - val_loss: 0.6958
# Epoch 8/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5375 - loss: 0.6895 - val_accuracy: 0.4500 - val_loss: 0.6980
# Epoch 9/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5250 - loss: 0.6890 - val_accuracy: 0.4000 - val_loss: 0.7002
# Epoch 10/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5375 - loss: 0.6876 - val_accuracy: 0.4500 - val_loss: 0.7011
# Epoch 11/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5250 - loss: 0.6870 - val_accuracy: 0.4500 - val_loss: 0.7025
# Epoch 12/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5250 - loss: 0.6863 - val_accuracy: 0.4500 - val_loss: 0.7040
# Epoch 13/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5250 - loss: 0.6853 - val_accuracy: 0.4500 - val_loss: 0.7051
# Epoch 14/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5250 - loss: 0.6846 - val_accuracy: 0.4000 - val_loss: 0.7065
# Epoch 15/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5375 - loss: 0.6843 - val_accuracy: 0.4000 - val_loss: 0.7087
# Epoch 16/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5500 - loss: 0.6833 - val_accuracy: 0.4000 - val_loss: 0.7096
# Epoch 17/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5500 - loss: 0.6826 - val_accuracy: 0.4000 - val_loss: 0.7109
# Epoch 18/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5500 - loss: 0.6822 - val_accuracy: 0.4500 - val_loss: 0.7125
# Epoch 19/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5500 - loss: 0.6816 - val_accuracy: 0.4500 - val_loss: 0.7125
# Epoch 20/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5500 - loss: 0.6812 - val_accuracy: 0.4500 - val_loss: 0.7122
# Epoch 21/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5500 - loss: 0.6807 - val_accuracy: 0.4500 - val_loss: 0.7121
# Epoch 21: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step
